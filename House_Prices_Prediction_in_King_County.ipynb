# %% [markdown]
# <a href="https://colab.research.google.com/github/drakemirwin17-beep/Final-project123/blob/main/House_Prices_Prediction_in_King_County.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Housing Prices In King County, Washinton State

# %%
import pandas as pd
